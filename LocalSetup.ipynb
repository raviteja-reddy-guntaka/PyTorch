# %%
# python -m venv venv
# .\venv\Scripts\activate

# !pip --version

# Install the compatible CUDA Toolkit - https://developer.nvidia.com/cuda-toolkit-archive
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# pip 24.2 from C:\Users\tejar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip (python 3.12)

# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------
# aiohappyeyeballs                         2.4.6
# aiohttp                                  3.11.12
# aiosignal                                1.3.2
# alembic                                  1.13.1
# annotated-types                          0.7.0
# anyio                                    4.8.0
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.8.1
# asttokens                                3.0.0
# async-lru                                2.0.5
# attrs                                    25.1.0
# babel                                    2.17.0
# backoff                                  2.2.1
# bcrypt                                   4.0.1
# beautifulsoup4                           4.13.4
# bleach                                   6.2.0
# ...

# %%
import torch

print('Torch uses tensors. You can create a 5*3 tensor with this.')
x = torch.rand(5, 3)
print(x)
# Out:
# Torch uses tensors. You can create a 5*3 tensor with this.
# tensor([[0.9869, 0.5724, 0.2413],
#         [0.7258, 0.6881, 0.7981],
#         [0.7290, 0.2875, 0.6657],
#         [0.0220, 0.8345, 0.8012],
#         [0.4656, 0.2054, 0.8546]])

# %%
# CUDA 12.8
torch.cuda.is_available()
# Out:
# True
